# %%
# Run this once in a cell, then clear output / delete cell
import requests

# Paste your key here once
YOUTUBE_API_KEY = 'AIzaSyAuyqbrM7kekTKp4jT32PjmNJi7c611uYY'

# Write directly to Databricks Secrets via REST API
context = dbutils.notebook.entry_point.getDbutils().notebook().getContext()
host = context.apiUrl().get()
token = context.apiToken().get()

requests.post(
    f"{host}/api/2.0/secrets/put",
    headers={"Authorization": f"Bearer {token}"},
    json={
        "scope": "youtube_scope",
        "key": "api_key",
        "string_value": YOUTUBE_API_KEY
    }
)

# %%
# 1. Verify API secret retrieval
api_key = dbutils.secrets.get(scope="youtube_scope", key="api_key")
print("Secret Loaded Successfully:", len(api_key) > 0)

# 2. Verify UC Volume Landing Path
volume_path = "/Volumes/youtube_lakehouse/bronze/raw_landing"
print("Volume Accessible:", dbutils.fs.ls(volume_path))
